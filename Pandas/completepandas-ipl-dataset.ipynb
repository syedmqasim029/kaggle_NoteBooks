# %%
import pandas as pd

# %%
data = pd.read_csv("/kaggle/input/ipl-dataset/matches - matches.csv")

# %%
data.head(6)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
# for fetching rows
data.iloc[0:5]
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# fancy indexing
data.iloc[:,[4,5,10]].head(7)
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
# 5                Gujarat Lions          Sunrisers Hyderabad
# 6        Kolkata Knight Riders               Mumbai Indians
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore
# 5          Sunrisers Hyderabad
# 6               Mumbai Indians

# %%
# All the matched held in hyd in season 2016
data[(data['city'] == 'Hyderabad') & (data['season'] == 2016)]
# Out:
#       id  season       city        date                team1  \
# 583  584    2016  Hyderabad  2016-04-16  Sunrisers Hyderabad
# 587  588    2016  Hyderabad  2016-04-18       Mumbai Indians
# 593  594    2016  Hyderabad  2016-04-23      Kings XI Punjab
# 597  598    2016  Hyderabad  2016-04-26  Sunrisers Hyderabad
# 602  603    2016  Hyderabad  2016-04-30  Sunrisers Hyderabad
# 609  610    2016  Hyderabad  2016-05-06        Gujarat Lions
# 617  618    2016  Hyderabad  2016-05-12  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 583        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 587          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 593          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 597      Rising Pune Supergiants      Rising Pune Supergiants         field
# 602  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
# without using season col fetching data of year 2016
data[(data['date'] > '2016-01-01') & (data['date'] < '2017-01-01')]
# Out:
#       id  season           city        date                        team1  \
# 576  577    2016         Mumbai  2016-04-09               Mumbai Indians
# 577  578    2016        Kolkata  2016-04-10             Delhi Daredevils
# 578  579    2016     Chandigarh  2016-04-11              Kings XI Punjab
# 579  580    2016      Bangalore  2016-04-12  Royal Challengers Bangalore
# 580  581    2016        Kolkata  2016-04-13        Kolkata Knight Riders
# 581  582    2016         Rajkot  2016-04-14      Rising Pune Supergiants
# 582  583    2016          Delhi  2016-04-15              Kings XI Punjab
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 584  585    2016         Mumbai  2016-04-16               Mumbai Indians
# 585  586    2016     Chandigarh  2016-04-17      Rising Pune Supergiants
# 586  587    2016      Bangalore  2016-04-17  Royal Challengers Bangalore
# 587  588    2016      Hyderabad  2016-04-18               Mumbai Indians
# ...

# %%
# value_count
# value_count is a method that apply only on series
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
data[data['season']== 2017]['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 12
# Rising Pune Supergiant         10
# Kolkata Knight Riders           9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Delhi Daredevils                6
# Gujarat Lions                   4
# Royal Challengers Bangalore     3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data[data['season']== 2017]['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data[data['season']== 2016]['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['umpire1'].value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: ylabel='umpire1'>

# %%
data['umpire2'].value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: ylabel='umpire2'>

# %%
all_umpires = pd.concat([data['umpire1'], data['umpire2']])
all_umpires.value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: >

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
all_umpires = pd.concat([data['umpire1'], data['umpire2']])
all_umpires.value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: >

# %%
teams  = pd.concat((data['team1'],data['team2']))
teams.value_counts()
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# ## Sort values

# %%
(data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending=False).head(15)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
#data.sort_values('city',ascending=False,inplace=True)
# inplace makes permenent changes

# %%
data.sort_values("date")
# Out:
#     id  season        city        date                        team1  \
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# ..  ..     ...         ...         ...                          ...
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values(by=["city","date"],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates('city',keep="last").sort_values(['city'])
# Out:
#       id  season            city        date                        team1  \
# 475  476    2014       Abu Dhabi  2014-04-29             Rajasthan Royals
# 539  540    2015       Ahmedabad  2015-04-24             Rajasthan Royals
# 635  636    2016       Bangalore  2016-05-29          Sunrisers Hyderabad
# 164  165    2009    Bloemfontein  2009-05-17             Delhi Daredevils
# 129  130    2009       Cape Town  2009-04-26              Kings XI Punjab
# 171  172    2009       Centurion  2009-05-22             Delhi Daredevils
# 621  622    2016      Chandigarh  2016-05-15              Kings XI Punjab
# 562  563    2015         Chennai  2015-05-10          Chennai Super Kings
# 496  497    2014         Cuttack  2014-05-14               Mumbai Indians
# 634  635    2016           Delhi  2016-05-27                Gujarat Lions
# 449  450    2013      Dharamsala  2013-05-18              Kings XI Punjab
# 168  169    2009          Durban  2009-05-20          Chennai Super Kings
# ...

# %%
data.drop_duplicates(['season'],keep="last")[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
coy = pd.read_csv('/kaggle/input/fortune500-2017/Fortune 500 2017 - Fortune 500.csv')
coy.head(2)
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
#
#        Sector                                  Industry       Hqlocation  \
# 0   Retailing                     General Merchandisers  Bentonville, AR
# 1  Financials  Insurance: Property and Casualty (Stock)        Omaha, NE
#
#                 Hqaddr       Hqcity Hqstate  ...  \
# 0  702 S.W. Eighth St.  Bentonville      AR  ...
# 1      3555 Farnam St.        Omaha      NE  ...
#
#                                        Ceo-title  \
# 0  President, Chief Executive Officer & Director
# 1             Chairman & Chief Executive Officer
#
#                                       Address Ticker                 Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT    Wal-Mart Stores, Inc.
# ...

# %%
coy.columns
# Out:
# Index(['Rank', 'Title', 'Website', 'Employees', 'Sector', 'Industry',
#        'Hqlocation', 'Hqaddr', 'Hqcity', 'Hqstate', 'Hqzip', 'Hqtel', 'Ceo',
#        'Ceo-title', 'Address', 'Ticker', 'Fullname', 'Revenues', 'Revchange',
#        'Profits', 'Prftchange', 'Assets', 'Totshequity'],
#       dtype='object')

# %%
sector = coy.groupby('Sector')
len(sector)
# Out:
# 21

# %%
len(coy.columns)
# Out:
# 23

# %%
sector.size().sort_values(ascending=False)
# Out:
# Sector
# Financials                       84
# Energy                           57
# Retailing                        47
# Technology                       43
# Health Care                      38
# Wholesalers                      29
# Food, Beverages & Tobacco        24
# Business Services                20
# Materials                        19
# Industrials                      19
# Transportation                   17
# Chemicals                        14
# Engineering & Construction       13
# Household Products               12
# Aerospace & Defense              12
# Media                            11
# Telecommunications               10
# Hotels, Restaurants & Leisure    10
# Motor Vehicles & Parts            9
# Food & Drug Stores                7
# Apparel                           5
# dtype: int64

# %%
sector.get_group('Chemicals')
# Out:
#      Rank                     Title                     Website  Employees  \
# 61     62              Dow Chemical          http://www.dow.com      56000
# 112   113                    DuPont       http://www.dupont.com      46000
# 182   183            PPG Industries          http://www.ppg.com      47000
# 203   204                  Monsanto     http://www.monsanto.com      22450
# 210   211                    Ecolab       http://www.ecolab.com      47565
# 235   236          Sherwin-Williams      http://www.sherwin.com      42550
# 274   275                   Praxair      http://www.praxair.com      26498
# 288   289                  Huntsman     http://www.huntsman.com      15000
# 293   294  Air Products & Chemicals  http://www.airproducts.com      18450
# 308   309          Eastman Chemical      http://www.eastman.com      14000
# 376   377                    Mosaic     http://www.mosaicco.com       8700
# ...

# %%
sector.get_group('Chemicals').shape[0]
# Out:
# 14
